# %%
                                                        # covid-19 data ANALYSIS #

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('COVID19_Extended_Dataset_1007.csv')

# %%
data.head()
# Out:
#    Country        Date  Total Cases  Total Deaths  Recovered  Active Cases  \
# 0    India  01-05-2021     19164969        211853   15684406       3268710
# 1      USA  01-05-2021     32421442        576722   25000000       6844720
# 2   Brazil  01-05-2021     14725975        406437   13293037       1026501
# 3       UK  01-05-2021      4418530        127517    4150000        141013
# 4  Germany  01-05-2021      3381597         82850    3030000        268747
#
#    Vaccinated
# 0   150000000
# 1   240000000
# 2    50000000
# 3    47000000
# 4    35000000

# %%
data.columns
# Out:
# Index(['Country', 'Date', 'Total Cases', 'Total Deaths', 'Recovered',
#        'Active Cases', 'Vaccinated'],
#       dtype='object')

# %%
data.tail()
# Out:
#      Country        Date  Total Cases  Total Deaths  Recovered  Active Cases  \
# 1002      UK  23-05-2021     45981569        814765   30454185      14712619
# 1003  Brazil  30-05-2021     19979419        908017   13643664       5427738
# 1004   Italy  14-05-2021     45299330       1097741   37898021       6303568
# 1005   India  11-05-2021     43959467       1135717   38407871       4415879
# 1006  Canada  01-05-2021     20962342        322019   16070862       4569461
#
#       Vaccinated
# 1002   117533229
# 1003   277658844
# 1004    80654212
# 1005   168668044
# 1006   207102290

# %%
  data.describe()
# Out:
#         Total Cases  Total Deaths     Recovered  Active Cases    Vaccinated
# count  1.007000e+03  1.007000e+03  1.007000e+03  1.007000e+03  1.007000e+03
# mean   2.500590e+07  6.315237e+05  1.979509e+07  4.579292e+06  1.471154e+08
# std    1.421282e+07  5.488081e+05  1.170659e+07  4.020245e+06  8.674081e+07
# min    1.502280e+05  1.089000e+03  9.578200e+04  7.128000e+03  1.273483e+06
# 25%    1.290222e+07  1.837765e+05  1.013392e+07  1.255072e+06  7.116370e+07
# 50%    2.480468e+07  4.688560e+05  1.952943e+07  3.515653e+06  1.411252e+08
# 75%    3.693505e+07  9.595545e+05  2.880458e+07  6.996086e+06  2.230250e+08
# max    4.987821e+07  2.472060e+06  4.842801e+07  1.837564e+07  2.999475e+08

# %%
data.isnull()
# Out:
#       Country   Date  Total Cases  Total Deaths  Recovered  Active Cases  \
# 0       False  False        False         False      False         False
# 1       False  False        False         False      False         False
# 2       False  False        False         False      False         False
# 3       False  False        False         False      False         False
# 4       False  False        False         False      False         False
# ...       ...    ...          ...           ...        ...           ...
# 1002    False  False        False         False      False         False
# 1003    False  False        False         False      False         False
# 1004    False  False        False         False      False         False
# 1005    False  False        False         False      False         False
# 1006    False  False        False         False      False         False
#
#       Vaccinated
# 0          False
# 1          False
# 2          False
# 3          False
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Date', 'Total Cases', 'Total Deaths', 'Recovered',
#        'Active Cases', 'Vaccinated'],
#       dtype='object')

# %%
#########   relating the variable with scatterplots  #########

# %%
sns.relplot(x="Total Cases" ,y="Total Deaths" ,data=data)

# %%
sns.relplot(x="Date" ,y="Vaccinated" ,data=data)

# %%
sns.relplot(x='Country' ,y='Total Deaths',hue='Recovered' ,data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Country', 'Date', 'Total Cases', 'Total Deaths', 'Recovered',
#        'Active Cases', 'Vaccinated'],
#       dtype='object')

# %%
import seaborn as sns

sns.relplot(x='Total Cases', y='Vaccinated', kind='line', data=data)

# %%
sns.relplot(x='Country', y='Total Deaths', kind='line', data=data)

# %%
data.columns
# Out:
# Index(['Country', 'Date', 'Total Cases', 'Total Deaths', 'Recovered',
#        'Active Cases', 'Vaccinated'],
#       dtype='object')

# %%
sns.catplot(x='Date', y='Recovered',data=data)
